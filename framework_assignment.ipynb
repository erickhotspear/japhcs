# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("covid_19.csv")

# %%
df.head()
# Out:
#             country      continent  population         day  \
# 0      Saint-Helena         Africa      6115.0  2024-06-30
# 1  Falkland-Islands  South-America      3539.0  2024-06-30
# 2        Montserrat  North-America      4965.0  2024-06-30
# 3  Diamond-Princess            NaN         NaN  2024-06-30
# 4      Vatican-City         Europe       799.0  2024-06-30
#
#                         time  Cases  Recovered  Deaths    Tests
# 0  2024-06-30T16:15:16+00:00   2166        2.0     NaN      NaN
# 1  2024-06-30T16:15:16+00:00   1930     1930.0     NaN   8632.0
# 2  2024-06-30T16:15:16+00:00   1403     1376.0     8.0  17762.0
# 3  2024-06-30T16:15:16+00:00    712      699.0    13.0      NaN
# 4  2024-06-30T16:15:16+00:00     29       29.0     NaN      NaN

# %%
df.describe()
# Out:
#          population         Cases     Recovered        Deaths         Tests
# count  2.290000e+02  2.380000e+02  1.900000e+02  2.330000e+02  2.130000e+02
# mean   3.469404e+07  8.883449e+06  1.006214e+07  9.026621e+04  3.298829e+07
# std    1.386374e+08  5.193031e+07  5.555519e+07  5.163434e+05  1.198779e+08
# min    7.990000e+02  9.000000e+00  2.000000e+00  1.000000e+00  7.850000e+03
# 25%    4.454310e+05  2.741875e+04  2.197250e+04  2.250000e+02  3.478150e+05
# 50%    5.797805e+06  2.320425e+05  2.351455e+05  2.570000e+03  2.226216e+06
# 75%    2.210284e+07  1.565481e+06  2.078212e+06  1.805700e+04  1.346373e+07
# max    1.448471e+09  7.047539e+08  6.756198e+08  7.010681e+06  1.186852e+09

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 238 entries, 0 to 237
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   country     238 non-null    object
#  1   continent   236 non-null    object
#  2   population  229 non-null    float64
#  3   day         238 non-null    object
#  4   time        238 non-null    object
#  5   Cases       238 non-null    int64
#  6   Recovered   190 non-null    float64
#  7   Deaths      233 non-null    float64
#  8   Tests       213 non-null    float64
# dtypes: float64(4), int64(1), object(4)
# memory usage: 16.9+ KB

# %%
df.isna()
# Out:
#      country  continent  population    day   time  Cases  Recovered  Deaths  \
# 0      False      False       False  False  False  False      False    True
# 1      False      False       False  False  False  False      False    True
# 2      False      False       False  False  False  False      False   False
# 3      False       True        True  False  False  False      False   False
# 4      False      False       False  False  False  False      False    True
# ..       ...        ...         ...    ...    ...    ...        ...     ...
# 233    False      False       False  False  False  False      False   False
# 234    False      False       False  False  False  False      False   False
# 235    False      False       False  False  False  False      False   False
# 236    False      False       False  False  False  False       True   False
# 237    False      False       False  False  False  False      False   False
#
#      Tests
# 0     True
# 1    False
# 2    False
# ...

# %%
df.columns
# Out:
# Index(['country', 'continent', 'population', 'day', 'time', 'Cases',
#        'Recovered', 'Deaths', 'Tests'],
#       dtype='object')

# %%
df.country.count()
# Out:
# 238

# %%
df.Cases.sum()
# Out:
# 2114260949

# %%
df2=df[df.continent=="Africa"]

# %%
df2.head()
# Out:
#            country continent  population         day  \
# 0     Saint-Helena    Africa      6115.0  2024-06-30
# 5   Western-Sahara    Africa    626161.0  2024-06-30
# 14        Djibouti    Africa   1016097.0  2024-06-30
# 16         Eritrea    Africa   3662244.0  2024-06-30
# 17           Niger    Africa  26083660.0  2024-06-30
#
#                          time  Cases  Recovered  Deaths     Tests
# 0   2024-06-30T16:15:16+00:00   2166        2.0     NaN       NaN
# 5   2024-06-30T16:15:16+00:00     10        9.0     1.0       NaN
# 14  2024-06-30T16:15:15+00:00  15690    15427.0   189.0  305941.0
# 16  2024-06-30T16:15:15+00:00  10189    10086.0   103.0   23693.0
# 17  2024-06-30T16:15:15+00:00   9931     8890.0   312.0  254538.0

# %%
df2.Recovered.mean()
# Out:
# 409660.03846153844

# %%
df2.Cases.mean()
# Out:
# 435963.5254237288

# %%
#Identifying null values
df2.isna().head()
# Out:
#     country  continent  population    day   time  Cases  Recovered  Deaths  \
# 0     False      False       False  False  False  False      False   False
# 5     False      False       False  False  False  False      False   False
# 14    False      False       False  False  False  False      False   False
# 16    False      False       False  False  False  False      False   False
# 17    False      False       False  False  False  False      False   False
#
#     Tests
# 0   False
# 5   False
# 14  False
# 16  False
# 17  False

# %%
df2.columns
# Out:
# Index(['country', 'continent', 'population', 'day', 'time', 'Cases',
#        'Recovered', 'Deaths', 'Tests'],
#       dtype='object')

# %%
#Replacing null values
def filldeaths(a):
    return a.fillna(0)
def filltests(b):
    return b.fillna(1)

# %%
df2.columns
# Out:
# Index(['country', 'continent', 'population', 'day', 'time', 'Cases',
#        'Recovered', 'Deaths', 'Tests'],
#       dtype='object')

# %%
df2.Deaths=df2.Deaths.fillna(0)
df2.Tests=df2.Tests.fillna(1)
df2.Recovered=df2.Recovered.fillna(409660)
df2.Cases=df2.Cases.fillna(435963)
# Out:
# C:\Users\Erick\AppData\Local\Temp\ipykernel_25308\3188909650.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.Deaths=df2.Deaths.fillna(0)
# C:\Users\Erick\AppData\Local\Temp\ipykernel_25308\3188909650.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.Tests=df2.Tests.fillna(1)
# C:\Users\Erick\AppData\Local\Temp\ipykernel_25308\3188909650.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
df2.Deaths.head(1)
# Out:
# 0    0.0
# Name: Deaths, dtype: float64

# %%
df2.head()
# Out:
#            country continent  population         day  \
# 0     Saint-Helena    Africa      6115.0  2024-06-30
# 5   Western-Sahara    Africa    626161.0  2024-06-30
# 14        Djibouti    Africa   1016097.0  2024-06-30
# 16         Eritrea    Africa   3662244.0  2024-06-30
# 17           Niger    Africa  26083660.0  2024-06-30
#
#                          time  Cases  Recovered  Deaths     Tests
# 0   2024-06-30T16:15:16+00:00   2166        2.0     0.0       1.0
# 5   2024-06-30T16:15:16+00:00     10        9.0     1.0       1.0
# 14  2024-06-30T16:15:15+00:00  15690    15427.0   189.0  305941.0
# 16  2024-06-30T16:15:15+00:00  10189    10086.0   103.0   23693.0
# 17  2024-06-30T16:15:15+00:00   9931     8890.0   312.0  254538.0

# %%
df2.Recovered.isna()
# Out:
# 0      False
# 5      False
# 14     False
# 16     False
# 17     False
# 18     False
# 19     False
# 23     False
# 25     False
# 26     False
# 27     False
# 35     False
# 38     False
# 44     False
# 49     False
# 52     False
# 59     False
# 60     False
# 61     False
# 64     False
# 65     False
# 66     False
# 67     False
# 70     False
# 71     False
# 72     False
# 75     False
# 76     False
# 77     False
# 78     False
# 79     False
# 82     False
# 84     False
# 98     False
# 99     False
# 100    False
# 103    False
# 104    False
# 107    False
# 108    False
# 109    False
# 110    False
# 111    False
# 114    False
# 119    False
# 141    False
# 142    False
# 143    False
# 150    False
# 151    False
# 154    False
# 156    False
# 157    False
# 158    False
# 160    False
# 166    False
# 205    False
# 209    False
# 217    False
# Name: Recovered, dtype: bool

# %%
df2.Recovered.sum()
# Out:
# 24169942.269230768

# %%
df2.Deaths.max()
# Out:
# 258892.0

# %%
df2.Deaths.mode()
# Out:
# 0    1468.0
# Name: Deaths, dtype: float64

# %%
country=df2.loc[df.Deaths==1468.0]

# %%
#country with high deaths  in Africa
country
# Out:
#     country continent  population         day                       time  \
# 103  Rwanda    Africa  13600464.0  2024-06-30  2024-06-30T16:15:13+00:00
# 108     DRC    Africa  95240792.0  2024-06-30  2024-06-30T16:15:13+00:00
#
#       Cases  Recovered  Deaths      Tests
# 103  133518   132039.0  1468.0  6021981.0
# 108   99338    84489.0  1468.0   846704.0

# %%
#Country with highest recovery in Africa

df2.Recovered.mode().head()
# Out:
# 0    409660.038462
# Name: Recovered, dtype: float64

# %%
cty=df2.loc[df.Recovered==3912506.0]

# %%
cty
# Out:
#           country continent  population         day  \
# 166  South-Africa    Africa  60756135.0  2024-06-30
#
#                           time    Cases  Recovered    Deaths       Tests
# 166  2024-06-30T16:15:11+00:00  4076463  3912506.0  102595.0  26795090.0

# %%
corri=df[['population','Cases','Recovered','Deaths','Tests']]

# %%
corri.head()
# Out:
#    population  Cases  Recovered  Deaths    Tests
# 0      6115.0   2166        2.0     NaN      NaN
# 1      3539.0   1930     1930.0     NaN   8632.0
# 2      4965.0   1403     1376.0     8.0  17762.0
# 3         NaN    712      699.0    13.0      NaN
# 4       799.0     29       29.0     NaN      NaN

# %%
corri.corr()
# Out:
#             population     Cases  Recovered    Deaths     Tests
# population    1.000000  0.367741   0.237196  0.404331  0.540603
# Cases         0.367741  1.000000   0.999918  0.985558  0.837956
# Recovered     0.237196  0.999918   1.000000  0.986204  0.862615
# Deaths        0.404331  0.985558   0.986204  1.000000  0.801020
# Tests         0.540603  0.837956   0.862615  0.801020  1.000000

# %%
sns.heatmap(data=corri.corr(),annot=True)
# Out:
# <Axes: >

# %%
sns.pairplot(df2)

# %%
x=df2[[ 'Cases',
        'Recovered', 'Tests']]
y=df2['Deaths']

# %%
x.isna().head()
# Out:
#     Cases  Recovered  Tests
# 0   False      False  False
# 5   False      False  False
# 14  False      False  False
# 16  False      False  False
# 17  False      False  False

# %%
from  sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=150)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lg=LogisticRegression()

# %%
lg.fit(x_train,y_train)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
pred=lg.predict(x)

# %%
plt.scatter(y,pred)
plt.show()

# %%
sns.histplot(y-pred)
# Out:
# <Axes: xlabel='Deaths', ylabel='Count'>

# %%
import streamlit as st
st.title("COVID Death Prediction Model")

cases = st.number_input("Cases", min_value=0)
recovered = st.number_input("Recovered", min_value=0)
tests = st.number_input("Tests", min_value=0)

if st.button("Predict"):
    input_data = pd.DataFrame([[cases, recovered, tests]], columns=X.columns)
    prediction = model.predict(input_data)
    st.success(f"Predicted Deaths: {int(prediction[0])}")
