# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
hs=pd.read_csv('housing.csv')

# %%
hs.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
hs.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
hs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
hs.columns[::].dtype
# Out:
# dtype('O')

# %%
hs.head(2)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY

# %%
sns.histplot(hs.median_house_value,kde=True)
plt.show()

# %%
pv=hs.pivot_table(index="ocean_proximity",columns='median_income',values='median_house_value')
pv
# Out:
# median_income          0.4999         0.5360   0.5495    0.6433    0.6775   \
# ocean_proximity
# <1H OCEAN        251033.666667  362500.000000  91700.0       NaN  350000.0
# INLAND           142837.625000  111785.571429      NaN       NaN       NaN
# ISLAND                     NaN            NaN      NaN       NaN       NaN
# NEAR BAY          67500.000000            NaN      NaN       NaN       NaN
# NEAR OCEAN                 NaN  162500.000000      NaN  111300.0       NaN
#
# median_income     0.6825   0.6831   0.6960   0.6991    0.7007   ...   13.8556  \
# ocean_proximity                                                 ...
# <1H OCEAN             NaN  87500.0      NaN      NaN  134400.0  ...  500001.0
# INLAND           187500.0      NaN  42500.0  89500.0       NaN  ...       NaN
# ISLAND                NaN      NaN      NaN      NaN       NaN  ...       NaN
# NEAR BAY              NaN      NaN      NaN      NaN       NaN  ...       NaN
# ...

# %%
cr=pv.corr()
cr
# Out:
# median_income   0.4999    0.5360   0.5495   0.6433   0.6775   0.6825   \
# median_income
# 0.4999         1.000000  1.000000      NaN      NaN      NaN      NaN
# 0.5360         1.000000  1.000000      NaN      NaN      NaN      NaN
# 0.5495              NaN       NaN      NaN      NaN      NaN      NaN
# 0.6433              NaN       NaN      NaN      NaN      NaN      NaN
# 0.6775              NaN       NaN      NaN      NaN      NaN      NaN
# ...                 ...       ...      ...      ...      ...      ...
# 14.4219             NaN       NaN      NaN      NaN      NaN      NaN
# 14.5833             NaN       NaN      NaN      NaN      NaN      NaN
# 14.9009             NaN       NaN      NaN      NaN      NaN      NaN
# 15.0000             NaN       NaN      NaN      NaN      NaN      NaN
# 15.0001       -0.912844 -0.981533      NaN      NaN      NaN      NaN
#
# median_income  0.6831   0.6960   0.6991   0.7007   ...  13.8556  13.9470  \
# ...

# %%
df=hs.drop(columns=['ocean_proximity','median_house_value','total_bedrooms'])

# %%
df.head(1)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  population  \
# 0    -122.23     37.88                41.0        880.0       322.0
#
#    households  median_income
# 0       126.0         8.3252

# %%
df.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'population', 'households', 'median_income'],
#       dtype='object')

# %%
df.isnull()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  population  \
# 0          False     False               False        False       False
# 1          False     False               False        False       False
# 2          False     False               False        False       False
# 3          False     False               False        False       False
# 4          False     False               False        False       False
# ...          ...       ...                 ...          ...         ...
# 20635      False     False               False        False       False
# 20636      False     False               False        False       False
# 20637      False     False               False        False       False
# 20638      False     False               False        False       False
# 20639      False     False               False        False       False
#
#        households  median_income
# 0           False          False
# 1           False          False
# ...

# %%
sns.heatmap(df.isna())
plt.show()

# %%
#x=df[['longitude', 'latitude', 'housing_median_age', 'total_rooms', 'population', 'households', 'median_income']]
x=df.median_income.values.reshape(-1,1)

# %%
y=hs.median_house_value

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.3,random_state=101)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
p=lr.predict(x)

# %%
plt.plot(x,p)
plt.scatter(x,p)
plt.show()

# %%
from sklearn import metrics

# %%
r2=metrics.mean_squared_error(x,p)

# %%
r2
# Out:
# 49018244836.42999
